# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models, datasets
from tensorflow.keras.utils import to_categorical
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import BatchNormalization

# Завантаження та розділення датасету
(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()

classes = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']

plt.figure(figsize=(10,10))
for i in range(100,150):
    plt.subplot(5,10,i-100+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xlabel(classes[np.squeeze(y_train[i])])

# Нормалізація даних
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# Перетворення міток в категоріальні дані
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# Визначення моделі з архітектурою Conv2D
model = models.Sequential([
    layers.Conv2D(64, (3, 3), activation='relu', input_shape=(32, 32, 3)),
    BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    layers.Conv2D(128, (3, 3), activation='relu'),
    BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    layers.Conv2D(256, (3, 3), activation='relu'),
    BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    BatchNormalization(),
    layers.Dropout(0.5),

    layers.Dense(10, activation='softmax')
])

# Компіляція моделі
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Виведення інформації про модель
model.summary()

datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

datagen.fit(x_train)


history = model.fit(datagen.flow(x_train, y_train, batch_size=64),
                    epochs=50,  # Increase the number of epochs
                    validation_data=(x_val, y_val))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 64)        1792
#
#  batch_normalization (Batch  (None, 30, 30, 64)        256
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 15, 15, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 128)       73856
#
#  batch_normalization_1 (Bat  (None, 13, 13, 128)       512
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 128)         0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 128)         0
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 256)         295168
#
#  batch_normalization_2 (Bat  (None, 4, 4, 256)         1024
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 2, 2, 256)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 2, 2, 256)         0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 512)               524800
#
#  batch_normalization_3 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 904586 (3.45 MB)
# Trainable params: 902666 (3.44 MB)
# Non-trainable params: 1920 (7.50 KB)
# _________________________________________________________________
# Epoch 1/50
# 625/625 [==============================] - 230s 364ms/step - loss: 1.8942 - accuracy: 0.3736 - val_loss: 1.5636 - val_accuracy: 0.4652
# Epoch 2/50
# 625/625 [==============================] - 232s 372ms/step - loss: 1.4021 - accuracy: 0.5004 - val_loss: 1.3797 - val_accuracy: 0.5014
# Epoch 3/50
# 625/625 [==============================] - 224s 359ms/step - loss: 1.2492 - accuracy: 0.5541 - val_loss: 1.7725 - val_accuracy: 0.4739
# Epoch 4/50
# 625/625 [==============================] - 225s 361ms/step - loss: 1.1666 - accuracy: 0.5872 - val_loss: 1.1013 - val_accuracy: 0.6134
# Epoch 5/50
# 625/625 [==============================] - 235s 375ms/step - loss: 1.0956 - accuracy: 0.6163 - val_loss: 1.1540 - val_accuracy: 0.5993
# Epoch 6/50
# 625/625 [==============================] - 235s 376ms/step - loss: 1.0510 - accuracy: 0.6327 - val_loss: 0.8693 - val_accuracy: 0.6912
# Epoch 7/50
# 625/625 [==============================] - 235s 376ms/step - loss: 1.0039 - accuracy: 0.6461 - val_loss: 0.8615 - val_accuracy: 0.6959
# Epoch 8/50
# 625/625 [==============================] - 236s 377ms/step - loss: 0.9672 - accuracy: 0.6620 - val_loss: 0.9197 - val_accuracy: 0.6743
# Epoch 9/50
# 625/625 [==============================] - 228s 364ms/step - loss: 0.9486 - accuracy: 0.6677 - val_loss: 1.0656 - val_accuracy: 0.6319
# Epoch 10/50
# 625/625 [==============================] - 227s 364ms/step - loss: 0.9222 - accuracy: 0.6776 - val_loss: 0.7907 - val_accuracy: 0.7193
# Epoch 11/50
# 625/625 [==============================] - 227s 363ms/step - loss: 0.8946 - accuracy: 0.6876 - val_loss: 0.7511 - val_accuracy: 0.7412
# Epoch 12/50
# 625/625 [==============================] - 227s 364ms/step - loss: 0.8787 - accuracy: 0.6938 - val_loss: 0.7378 - val_accuracy: 0.7452
# Epoch 13/50
# 625/625 [==============================] - 227s 363ms/step - loss: 0.8548 - accuracy: 0.7006 - val_loss: 0.7104 - val_accuracy: 0.7552
# Epoch 14/50
# 625/625 [==============================] - 235s 376ms/step - loss: 0.8399 - accuracy: 0.7102 - val_loss: 0.8625 - val_accuracy: 0.6970
# Epoch 15/50
# 625/625 [==============================] - 237s 379ms/step - loss: 0.8248 - accuracy: 0.7124 - val_loss: 0.7389 - val_accuracy: 0.7430
# Epoch 16/50
# 625/625 [==============================] - 228s 365ms/step - loss: 0.8101 - accuracy: 0.7172 - val_loss: 0.8794 - val_accuracy: 0.7015
# Epoch 17/50
# 625/625 [==============================] - 236s 377ms/step - loss: 0.7987 - accuracy: 0.7202 - val_loss: 0.7152 - val_accuracy: 0.7498
# Epoch 18/50
# 625/625 [==============================] - 237s 379ms/step - loss: 0.7754 - accuracy: 0.7280 - val_loss: 0.8742 - val_accuracy: 0.7060
# Epoch 19/50
# 625/625 [==============================] - 237s 379ms/step - loss: 0.7804 - accuracy: 0.7282 - val_loss: 0.7928 - val_accuracy: 0.7376
# Epoch 20/50
# 625/625 [==============================] - 226s 362ms/step - loss: 0.7620 - accuracy: 0.7339 - val_loss: 0.7396 - val_accuracy: 0.7486
# Epoch 21/50
# 625/625 [==============================] - 226s 362ms/step - loss: 0.7604 - accuracy: 0.7348 - val_loss: 0.6589 - val_accuracy: 0.7696
# Epoch 22/50
# 625/625 [==============================] - 227s 363ms/step - loss: 0.7515 - accuracy: 0.7384 - val_loss: 0.8532 - val_accuracy: 0.7086
# Epoch 23/50
# 625/625 [==============================] - 225s 360ms/step - loss: 0.7386 - accuracy: 0.7421 - val_loss: 1.1510 - val_accuracy: 0.6581
# Epoch 24/50
# 625/625 [==============================] - 237s 379ms/step - loss: 0.7304 - accuracy: 0.7444 - val_loss: 0.6689 - val_accuracy: 0.7745
# Epoch 25/50
# 625/625 [==============================] - 227s 363ms/step - loss: 0.7264 - accuracy: 0.7486 - val_loss: 0.7225 - val_accuracy: 0.7510
# Epoch 26/50
# 625/625 [==============================] - 226s 361ms/step - loss: 0.7109 - accuracy: 0.7521 - val_loss: 0.5541 - val_accuracy: 0.8089
# Epoch 27/50
# 625/625 [==============================] - 228s 364ms/step - loss: 0.7039 - accuracy: 0.7532 - val_loss: 0.6265 - val_accuracy: 0.7851
# Epoch 28/50
# 625/625 [==============================] - 228s 364ms/step - loss: 0.7028 - accuracy: 0.7565 - val_loss: 0.6347 - val_accuracy: 0.7826
# Epoch 29/50
# 625/625 [==============================] - 226s 361ms/step - loss: 0.6935 - accuracy: 0.7586 - val_loss: 0.5627 - val_accuracy: 0.8031
# Epoch 30/50
# 625/625 [==============================] - 236s 378ms/step - loss: 0.6866 - accuracy: 0.7615 - val_loss: 0.6192 - val_accuracy: 0.7867
# Epoch 31/50
# 625/625 [==============================] - 226s 362ms/step - loss: 0.6827 - accuracy: 0.7617 - val_loss: 0.5836 - val_accuracy: 0.8002
# Epoch 32/50
# 625/625 [==============================] - 226s 362ms/step - loss: 0.6839 - accuracy: 0.7618 - val_loss: 0.6316 - val_accuracy: 0.7835
# Epoch 33/50
# 625/625 [==============================] - 225s 360ms/step - loss: 0.6674 - accuracy: 0.7658 - val_loss: 0.7711 - val_accuracy: 0.7399
# Epoch 34/50
# 625/625 [==============================] - 227s 363ms/step - loss: 0.6621 - accuracy: 0.7670 - val_loss: 0.7894 - val_accuracy: 0.7389
# Epoch 35/50
# 625/625 [==============================] - 228s 364ms/step - loss: 0.6669 - accuracy: 0.7689 - val_loss: 0.5766 - val_accuracy: 0.8027
# Epoch 36/50
# 625/625 [==============================] - 235s 375ms/step - loss: 0.6605 - accuracy: 0.7703 - val_loss: 0.5695 - val_accuracy: 0.8051
# Epoch 37/50
# 625/625 [==============================] - 227s 363ms/step - loss: 0.6607 - accuracy: 0.7707 - val_loss: 0.5477 - val_accuracy: 0.8122
# Epoch 38/50
# 625/625 [==============================] - 235s 377ms/step - loss: 0.6568 - accuracy: 0.7704 - val_loss: 0.4973 - val_accuracy: 0.8265
# Epoch 39/50
# 625/625 [==============================] - 225s 361ms/step - loss: 0.6477 - accuracy: 0.7760 - val_loss: 0.6376 - val_accuracy: 0.7810
# Epoch 40/50
# 625/625 [==============================] - 225s 360ms/step - loss: 0.6423 - accuracy: 0.7757 - val_loss: 0.5293 - val_accuracy: 0.8159
# Epoch 41/50
# 625/625 [==============================] - 234s 375ms/step - loss: 0.6457 - accuracy: 0.7756 - val_loss: 0.5673 - val_accuracy: 0.8043
# Epoch 42/50
# 625/625 [==============================] - 235s 376ms/step - loss: 0.6369 - accuracy: 0.7766 - val_loss: 0.6030 - val_accuracy: 0.7942
# Epoch 43/50
# 625/625 [==============================] - 237s 379ms/step - loss: 0.6374 - accuracy: 0.7796 - val_loss: 0.8087 - val_accuracy: 0.7378
# Epoch 44/50
# 625/625 [==============================] - 226s 362ms/step - loss: 0.6316 - accuracy: 0.7790 - val_loss: 0.5439 - val_accuracy: 0.8138
# Epoch 45/50
# 625/625 [==============================] - 244s 391ms/step - loss: 0.6269 - accuracy: 0.7819 - val_loss: 0.6218 - val_accuracy: 0.7917
# Epoch 46/50
# 625/625 [==============================] - 244s 390ms/step - loss: 0.6204 - accuracy: 0.7828 - val_loss: 0.5045 - val_accuracy: 0.8280
# Epoch 47/50
# 625/625 [==============================] - 236s 378ms/step - loss: 0.6227 - accuracy: 0.7835 - val_loss: 0.5028 - val_accuracy: 0.8291
# Epoch 48/50
# 625/625 [==============================] - 235s 376ms/step - loss: 0.6127 - accuracy: 0.7853 - val_loss: 0.5882 - val_accuracy: 0.7992
# Epoch 49/50
# 625/625 [==============================] - 229s 366ms/step - loss: 0.6145 - accuracy: 0.7868 - val_loss: 0.7011 - val_accuracy: 0.7607
# Epoch 50/50
# 625/625 [==============================] - 235s 376ms/step - loss: 0.6146 - accuracy: 0.7857 - val_loss: 0.5681 - val_accuracy: 0.8055

# %%
# Виведення графіків функції втрат та точності
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title("Графік функції втрат")
plt.legend()
plt.grid()
plt.show()

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title("Графік точності")
plt.grid()
plt.legend()
plt.show()

# %%
# Оцінка точності на тестовому наборі
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=2)
print(f"\nTest Accuracy: {test_accuracy*100:.2f}%")


# Виведення статистики моделі
print("\nModel Evaluation:")
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy*100:.2f}%")

# Статистика параметрів моделі
total_parameters = sum([np.prod(layer.get_weights()[i].shape) for layer in model.layers for i in range(len(layer.get_weights()))])

print(f"\nTotal Parameters: {total_parameters}")

# Статистика шарів моделі
for i, layer in enumerate(model.layers):
    print(f"\nLayer {i + 1}: {layer.name}")
    print(f"Number of Parameters: {layer.count_params()}")
    print(f"Input Shape: {layer.input_shape}, Output Shape: {layer.output_shape}")
# Out:
# 313/313 - 10s - loss: 0.5871 - accuracy: 0.7999 - 10s/epoch - 33ms/step
#
# Test Accuracy: 79.99%
#
# Model Evaluation:
# Test Loss: 0.5871
# Test Accuracy: 79.99%
#
# Total Parameters: 904586
#
# Layer 1: conv2d
# Number of Parameters: 1792
# Input Shape: (None, 32, 32, 3), Output Shape: (None, 30, 30, 64)
#
# Layer 2: batch_normalization
# Number of Parameters: 256
# Input Shape: (None, 30, 30, 64), Output Shape: (None, 30, 30, 64)
#
# Layer 3: max_pooling2d
# Number of Parameters: 0
# Input Shape: (None, 30, 30, 64), Output Shape: (None, 15, 15, 64)
#
# Layer 4: dropout
# Number of Parameters: 0
# Input Shape: (None, 15, 15, 64), Output Shape: (None, 15, 15, 64)
#
# Layer 5: conv2d_1
# Number of Parameters: 73856
# Input Shape: (None, 15, 15, 64), Output Shape: (None, 13, 13, 128)
#
# Layer 6: batch_normalization_1
# Number of Parameters: 512
# Input Shape: (None, 13, 13, 128), Output Shape: (None, 13, 13, 128)
#
# Layer 7: max_pooling2d_1
# Number of Parameters: 0
# Input Shape: (None, 13, 13, 128), Output Shape: (None, 6, 6, 128)
#
# Layer 8: dropout_1
# Number of Parameters: 0
# Input Shape: (None, 6, 6, 128), Output Shape: (None, 6, 6, 128)
#
# Layer 9: conv2d_2
# Number of Parameters: 295168
# Input Shape: (None, 6, 6, 128), Output Shape: (None, 4, 4, 256)
#
# Layer 10: batch_normalization_2
# Number of Parameters: 1024
# Input Shape: (None, 4, 4, 256), Output Shape: (None, 4, 4, 256)
#
# Layer 11: max_pooling2d_2
# Number of Parameters: 0
# Input Shape: (None, 4, 4, 256), Output Shape: (None, 2, 2, 256)
#
# Layer 12: dropout_2
# Number of Parameters: 0
# Input Shape: (None, 2, 2, 256), Output Shape: (None, 2, 2, 256)
#
# Layer 13: flatten
# Number of Parameters: 0
# Input Shape: (None, 2, 2, 256), Output Shape: (None, 1024)
#
# Layer 14: dense
# Number of Parameters: 524800
# Input Shape: (None, 1024), Output Shape: (None, 512)
#
# Layer 15: batch_normalization_3
# Number of Parameters: 2048
# Input Shape: (None, 512), Output Shape: (None, 512)
#
# Layer 16: dropout_3
# Number of Parameters: 0
# Input Shape: (None, 512), Output Shape: (None, 512)
#
# Layer 17: dense_1
# Number of Parameters: 5130
# Input Shape: (None, 512), Output Shape: (None, 10)

# %%
model.save("model.h5")
